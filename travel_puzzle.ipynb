# %%
import pandas as pd

# %%
df = pd.read_csv('puzzle.csv', header=None)
df.head()
# Out:
#          0         1
# 0  0.39715  2.113629
# 1  0.39715  2.113629
# 2  0.39715  2.113629
# 3  0.39715  2.113629
# 4  0.39715  2.113629

# %%
df.describe()
# Out:
#                  0            1
# count  1024.000000  1024.000000
# mean      0.504729    -0.388165
# std       0.355107     1.499346
# min      -0.925070    -2.837888
# 25%       0.389721    -1.559228
# 50%       0.591392    -1.129903
# 75%       0.746583     0.578621
# max       1.195399     3.096964

# %%
df.isnull().sum()
# Out:
# 0    0
# 1    0
# dtype: int64

# %%
df['sum'] = df.sum(axis=1)

# %%
df.head()
# Out:
#          0         1       sum
# 0  0.39715  2.113629  2.510778
# 1  0.39715  2.113629  2.510778
# 2  0.39715  2.113629  2.510778
# 3  0.39715  2.113629  2.510778
# 4  0.39715  2.113629  2.510778

# %%
df.nunique()
# Out:
# 0      912
# 1      912
# sum    912
# dtype: int64

# %%
df.head(30)
# Out:
#            0         1       sum
# 0   0.397150  2.113629  2.510778
# 1   0.397150  2.113629  2.510778
# 2   0.397150  2.113629  2.510778
# 3   0.397150  2.113629  2.510778
# 4   0.397150  2.113629  2.510778
# 5   0.397150  2.113629  2.510778
# 6   0.397150  2.113629  2.510778
# 7   0.397150  2.113629  2.510778
# 8   0.967562 -0.099246  0.868315
# 9   0.061841 -1.333110 -1.271270
# 10  0.719915 -0.151519  0.568396
# 11  0.759443  0.761602  1.521046
# 12  0.930847 -0.049737  0.881110
# 13  0.505194 -0.237455  0.267739
# 14  0.745198  0.408607  1.153805
# 15 -0.388084  1.991229  1.603144
# 16  0.132041 -1.257250 -1.125209
# 17  0.715182  0.502910  1.218091
# 18  1.067695 -2.617924 -1.550229
# 19  0.897974  0.093803  0.991777
# 20  0.636612 -1.438281 -0.801668
# 21  0.690307  0.047801  0.738109
# 22 -0.388084  1.991229  1.603144
# 23  0.105732  2.183337  2.289069
# 24  0.713595  0.249422  0.963017
# 25  0.900091  0.012140  0.912230
# 26  0.895171  0.118103  1.013273
# ...

# %%
df['diff'] = df[1] - df[0]

# %%
df.head(30)
# Out:
#            0         1       sum      diff
# 0   0.397150  2.113629  2.510778  1.716479
# 1   0.397150  2.113629  2.510778  1.716479
# 2   0.397150  2.113629  2.510778  1.716479
# 3   0.397150  2.113629  2.510778  1.716479
# 4   0.397150  2.113629  2.510778  1.716479
# 5   0.397150  2.113629  2.510778  1.716479
# 6   0.397150  2.113629  2.510778  1.716479
# 7   0.397150  2.113629  2.510778  1.716479
# 8   0.967562 -0.099246  0.868315 -1.066808
# 9   0.061841 -1.333110 -1.271270 -1.394951
# 10  0.719915 -0.151519  0.568396 -0.871434
# 11  0.759443  0.761602  1.521046  0.002159
# 12  0.930847 -0.049737  0.881110 -0.980584
# 13  0.505194 -0.237455  0.267739 -0.742650
# 14  0.745198  0.408607  1.153805 -0.336591
# 15 -0.388084  1.991229  1.603144  2.379313
# 16  0.132041 -1.257250 -1.125209 -1.389290
# 17  0.715182  0.502910  1.218091 -0.212272
# 18  1.067695 -2.617924 -1.550229 -3.685619
# 19  0.897974  0.093803  0.991777 -0.804170
# 20  0.636612 -1.438281 -0.801668 -2.074893
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(10, 10))

sns.scatterplot(df[0], df[1]);

# %%
plt.figure(figsize=(15, 10))

sns.scatterplot(df[1], df[0]);

# %%
df['product'] = df[0] * df[1]

# %%
df.head(30)

# %%
df.describe()
# Out:
#                  0            1          sum         diff      product
# count  1024.000000  1024.000000  1024.000000  1024.000000  1024.000000
# mean      0.504729    -0.388165     0.116564    -0.892894    -0.327674
# std       0.355107     1.499346     1.452711     1.624164     0.850233
# min      -0.925070    -2.837888    -2.935564    -4.005246    -3.312832
# 25%       0.389721    -1.559228    -1.095683    -2.180113    -0.996131
# 50%       0.591392    -1.129903    -0.646679    -1.312695    -0.252911
# 75%       0.746583     0.578621     1.276282     0.074248     0.330857
# max       1.195399     3.096964     3.219560     3.772218     1.846257

# %%
df.nunique()
# Out:
# 0          912
# 1          912
# sum        912
# diff       912
# product    912
# dtype: int64

# %% [markdown]
# ## Thoughts so far
#
# So far what I am seeing is that there are pairs between columns 0 and 1. There are 1024 rows and of those 1024 rows, there are 912 unique values.
#
# It is possible that there are not 912 unique pairs, but the sum, diff, and product make me think that any 0 value has a distinct 1 value pair.
#
#
# ## Thoughts after filpping the scatterplot sideways
#
# It seems to resemble a map of the world, maybe it is some form of scaled longitude and latitude
